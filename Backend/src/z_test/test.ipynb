# %%
#!python
(
#!html
<!DOCTYPE html>
<body>
    <div>
        <p>
            hello world
        </p>
    </div>
</body>
#!python
)
from IPython.display import HTML, display

html_content = "<h1>Hello World</h1><p>This is HTML in a notebook.</p>"
display(HTML(html_content))
# Out:
#   Cell In[2], line 4
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax
